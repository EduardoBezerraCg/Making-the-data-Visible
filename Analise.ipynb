# %%
#Começamos por importar nossas bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importando nossa BD
dev_mun = pd.read_csv('dados.csv', sep=';')
dev_mun.head()
# Out:
#    CODIGO               MUNICIPIO       PIB  VALOREMPENHO
# 0     106   SANTANA DO LIVRAMENTO  12240.76    1088666.10
# 1     113            SANTO ANGELO  16575.82     800669.92
# 2     118  SAO FRANCISCO DE ASSIS  12037.61     466122.80
# 3      13         CACAPAVA DO SUL  13674.54     485535.86
# 4     120             SAO GABRIEL  19912.38     533719.86

# %%
#Setar o tema
sns.set_theme(style='darkgrid')

# %%
cinco_maiores = dev_mun.sort_values(by='PIB', ascending=False).head(5)
cinco_maiores
# Out:
#      CODIGO          MUNICIPIO        PIB  VALOREMPENHO
# 49      149            TRIUNFO  223848.22    1442759.82
# 146     453      MUITOS CAPOES   72353.72     140597.55
# 91      356          GARRUCHOS   68672.25     271841.26
# 176     108  SANTA CRUZ DO SUL   40671.53       9637.00
# 155     476      CAPAO DO CIPO   36739.78      60851.00

# %%
#Criando o gráfico mostrando os 5 maiores
sns.barplot(x='PIB', y='MUNICIPIO', data=cinco_maiores)
plt.title('5 maiores PIBS')
# Out:
# Text(0.5, 1.0, '5 maiores PIBS')

# %%
#Obtendo os 5 menores
cinco_menores = dev_mun.sort_values(by=['PIB']).head(6)
cinco_menores
# Out:
#     CODIGO            MUNICIPIO       PIB  VALOREMPENHO
# 88     216            REDENTORA   8236.63      60134.00
# 11     248      AMARAL FERRADOR   9216.87     235327.02
# 15      38  ENCRUZILHADA DO SUL  10372.80     200738.61
# 66     414     SENTINELA DO SUL  10477.52      92380.20
# 89     413   SAO VALERIO DO SUL  10503.72      67638.25
# 6       95             PIRATINI  10811.67     315884.50

# %%
sns.barplot(x='PIB', y='MUNICIPIO', data=cinco_menores)
plt.title('Os 5 menores')
plt.tight_layout()

# %%
sns.histplot(dev_mun.VALOREMPENHO, kde=True, bins=10).set_title('VALOREMPENHO')
# Out:
# Text(0.5, 1.0, 'VALOREMPENHO')

# %%
#Calculando os 10 maiores
agrupado = dev_mun.sort_values(['VALOREMPENHO']).head(10)
agrupado = agrupado.iloc[:,[1,3]]
agrupado.plot.bar(x='MUNICIPIO', y='VALOREMPENHO', color='LightBlue')
plt.title('Top 10 Municípios com maior valor empenho')
# Out:
# Text(0.5, 1.0, 'Top 10 Municípios com maior valor empenho')

# %%
#
data1 = dev_mun.groupby(['VALOREMPENHO'])['MUNICIPIO'].sum()
data1
# Out:
# VALOREMPENHO
# 172.13                                      GUARANI DAS MISSOES
# 233.01                                           GETULIO VARGAS
# 310.58                                          NOVA SANTA RITA
# 365.00                                     SANTA BARBARA DO SUL
# 760.00        MATO LEITAOSANTA VITORIA DO PALMARMATO LEITAOS...
#                                     ...
# 485535.86                                       CACAPAVA DO SUL
# 533719.86                                           SAO GABRIEL
# 800669.92                                          SANTO ANGELO
# 1088666.10                                SANTANA DO LIVRAMENTO
# 1442759.82                                              TRIUNFO
# Name: MUNICIPIO, Length: 172, dtype: object

# %%
sns.histplot(data=dev_mun['PIB'], color='LightBlue', kde=True, stat='density', bins=15).set_title('PIB')
# Out:
# Text(0.5, 1.0, 'PIB')

# %%
#entendendo o PIB através do gráfico de dispersão
plt.scatter(x=dev_mun.MUNICIPIO.head(20), y=dev_mun.PIB.head(20), color='Brown', facecolors = 'none', marker='.')
plt.xlabel('Cidades')
plt.xticks(rotation=80)
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
#Experimentando integrar os 5 maiores apenas neste grafico
agrupado = dev_mun.sort_values(by=['PIB'], ascending=False).head(20)
agrupado
# Out:
#      CODIGO                MUNICIPIO        PIB  VALOREMPENHO
# 49      149                  TRIUNFO  223848.22    1442759.82
# 146     453            MUITOS CAPOES   72353.72     140597.55
# 91      356                GARRUCHOS   68672.25     271841.26
# 176     108        SANTA CRUZ DO SUL   40671.53       9637.00
# 155     476            CAPAO DO CIPO   36739.78      60851.00
# 68       75                    MARAU   34568.53     193840.83
# 145     276                 GLORINHA   33730.13      74325.48
# 169     329               VILA MARIA   31104.22      28149.89
# 175      96             PORTO ALEGRE   30524.80       9358.33
# 106     273        EUGENIO DE CASTRO   30468.92     105023.36
# 183     107     SANTA BARBARA DO SUL   29654.02        365.00
# 119     352                  COXILHA   29446.80      87241.91
# 160     295         NOVA ROMA DO SUL   29148.60      43757.70
# 150     211                 PEJUCARA   29005.14      59830.97
# ...

# %%
top5 = dev_mun['PIB'].nlargest(5)

# %%
plt.scatter(x='PIB', y='MUNICIPIO', data=agrupado)

# %%
plt.plot(top5, marker='.')

# %%
#Nesse caso é mais dificil criar uma linha de tendência devido a dispersão dos dados
sns.regplot(x=dev_mun.PIB.head(10), y=dev_mun.VALOREMPENHO.head(10), data=dev_mun, x_jitter=0.3, fit_reg=True)
# Out:
# <Axes: xlabel='PIB', ylabel='VALOREMPENHO'>

# %%
#Compilando o que analizamos
plt.figure(1)
plt.subplot(2,2,1)
plt.ylabel('Plot Graphic')
plt.scatter(dev_mun.PIB, dev_mun.VALOREMPENHO)

plt.subplot(2,2,2)
plt.scatter(x='PIB', y='MUNICIPIO', data=agrupado.head(10))
plt.ylabel('Scatter Graphic')

plt.subplot(2,2,3)
plt.plot(top5, marker='.')
plt.ylabel('Line Graphic')

plt.subplot(2,2,4)
sns.histplot(dev_mun.VALOREMPENHO, kde=True, bins=10)
plt.ylabel('Valor Empenho')

plt.tight_layout()
